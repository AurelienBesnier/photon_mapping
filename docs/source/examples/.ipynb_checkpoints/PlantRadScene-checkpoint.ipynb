# %% [markdown]
# # Simple simulation example

# %%
from openalea.photonmap.Simulator import Simulator
from openalea.photonmap import Vec3

# %% [markdown]
# ## Setup configuration

# %%
simulator = Simulator()
simulator.readConfiguration("simulation.ini")
simulator.addEnvFromFile("./assets/testChamber.rad", "./PO")
simulator.addVirtualDiskCaptorsFromFile("./captors/captors_expe1.csv")
simulator.addFaceCaptorsFromLpyFile("./assets/rose-simple4.lpy", Vec3(1280.0, 860.0, 980.0))

# %% [markdown]
# ## Run the simulation

# %%
res = simulator.run()
# Out:
# Wavelength: 600 - 655
# Transparent material: Makrolon
# Build photonMap...Backface Culling ON
#
# Maximum number of threads is 8
# nb photons per lights: 1250
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 30
# Done!
# calculating captor energy...
# calculating captor energy...
# Time taken: 0.9195675849914551

# %% [markdown]
# ## Calibrate the result

# %%
# calibrated_res = simulator.calibrateResults("spectrum/chambre1_spectrum", "points_calibration.csv")

# %% [markdown]
# ## Write the result

# %%
res.writeResults()
# Out:
# Done write captor energy!
# Done write captor energy!

# %% [markdown]
# ## Visualize scene with OAWidgets

# %%
simulator.visualiserSimulationScene("oawidgets")
# Out:
# Plot(antialias=3, axes=['x', 'y', 'z'], axes_helper=1.0, axes_helper_colors=[16711680, 65280, 255], background…

# %% [markdown]
# ## Test Tmin in complete scene

# %%
simulator.test_t_min(int(1e6), 1e-6, 11, False)
# Out:
# Transparent material: Makrolon
# ---------------------------------Backface Culling ON
#
# Test Tmin = 1e-06
# Number of photons received in total is 7993
# ---------------------------------
# ---------------------------------
# Test Tmin = 1e-05
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Number of photons received in total is 8056
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.0001
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...is
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
#  7651
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.001
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Number of photons received in total is 7473
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.01
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Number of photons received in total is 7467
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.1
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Number of photons received in total is 7478
# ---------------------------------
# ---------------------------------
# Test Tmin = 1.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Number of photons received in total is 7554
# ---------------------------------
# ---------------------------------
# Test Tmin = 10.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Number of photons received in total is 8562
# ---------------------------------
# ---------------------------------
# Test Tmin = 100.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 38
# Number of photons received in total is 8649
# ---------------------------------
# ---------------------------------
# Test Tmin = 1000.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 13
# Number of photons received in total is 2267
# ---------------------------------
# ---------------------------------
# Test Tmin = 10000.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 0
# Number of photons received in total is 0
# ---------------------------------

# %% [markdown]
# ## Test Tmin in scene with only lamps and captors

# %%
simulator.test_t_min(int(1e7), 1e-6, 11, True)
# Out:
# Transparent material: Makrolon
# ---------------------------------Backface Culling ON
#
# Test Tmin = 1e-06
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 3
# Number of photons received in total is 28269
# ---------------------------------
# ---------------------------------
# Test Tmin = 1e-05
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 3
# Number of photons received in total is 28269
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.0001
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 3
# Number of photons received in total is 28252
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.001
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 2
# Number of photons received in total is 25576
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.01
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 2
# Number of photons received in total is 25578
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.1
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 2
# Number of photons received in total is 25578
# ---------------------------------
# ---------------------------------
# Test Tmin = 1.0
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 2
# Number of photons received in total is 25578
# ---------------------------------
# ---------------------------------
# Test Tmin = 10.0
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 2
# Number of photons received in total is 25576
# ---------------------------------
# ---------------------------------
# Test Tmin = 100.0
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 2
# Number of photons received in total is 25556
# ---------------------------------
# ---------------------------------
# Test Tmin = 1000.0
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 1
# Number of photons received in total is 16540
# ---------------------------------
# ---------------------------------
# Test Tmin = 10000.0
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 0
# Number of photons received in total is 0
# ---------------------------------
