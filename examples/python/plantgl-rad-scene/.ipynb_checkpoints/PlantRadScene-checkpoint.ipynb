# %% [markdown]
# Import the modules necessary for simulation

# %%
from photonmap.Simulator import *

# %% [markdown]
# Setup configuration

# %%
simulator = Simulator()
simulator.readConfiguration("simulation.ini")

simulator.setupRoom("./assets/testChamber.rad", "./PO")
simulator.setupCaptor("./captors/captors_expe1.csv")
#simulator.setupPlant("./assets/rose-simple4.lpy", Vec3(1280.0, 860.0, 980.0))
# Out:
# Write .obj
# Write .obj.mtl

# %% [markdown]
# Run the simulation

# %%
res = simulator.run()
calibrated_res = simulator.calibrateResults("spectrum/chambre1_spectrum", "points_calibration.csv")

simulator.writeResults()
# Out:
# Wavelength: 600 - 655
# Transparent material: Makrolon
# Backface Culling ON
# Build photonMap...
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 30
# building captor photonmap...
# Number of photons on captor elements: 47439
# Done!
# Done!
# calculating captor energy...
# Time taken: 3.4188437461853027
# Wavelength: 655 - 665
# Transparent material: Makrolon
# Build photonMap...
# Backface Culling ON
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 31
# building captor photonmap...
# Number of photons on captor elements: 48016
# Done!
# Done!
# calculating captor energy...
# Time taken: 3.355682134628296
# Done write captor energy!

# %%
# %gui qt5
simulator.visualiserSimulationScene(-1, "ipython")

# %%
simulator.visualiserSimulationScene(-1, "pgljupyter")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 SceneWidget(spheres, size_display=(600, 400), size_world=255)
#
# NameError: name 'spheres' is not defined

# %% [markdown]
# Test Tmin in complete scene

# %%
simulator.test_t_min(int(1e6), 1e-6, 11, False)
# Out:
# Transparent material: Makrolon
# Backface Culling ON
# ---------------------------------
# Test Tmin = 1e-06
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 28
# building captor photonmap...
# Number of photons on captor elements: 5351
# Done!
# Number of photons received in total is 5351
# ---------------------------------
# ---------------------------------
# Test Tmin = 1e-05
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 26
# building captor photonmap...
# Number of photons on captor elements: 5396
# Done!
# Number of photons received in total is 5396
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.0001
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 30
# building captor photonmap...
# Number of photons on captor elements: 5047
# Done!
# Number of photons received in total is 5047
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.001
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 30
# building captor photonmap...
# Number of photons on captor elements: 4853
# Done!
# Number of photons received in total is 4853
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.01
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 30
# building captor photonmap...
# Number of photons on captor elements: 4855
# Done!
# Number of photons received in total is 4855
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.1
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 30
# building captor photonmap...
# Number of photons on captor elements: 4876
# Done!
# Number of photons received in total is 4876
# ---------------------------------
# ---------------------------------
# Test Tmin = 1.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 33
# building captor photonmap...
# Number of photons on captor elements: 4911
# Done!
# Number of photons received in total is 4911
# ---------------------------------
# ---------------------------------
# Test Tmin = 10.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 33
# building captor photonmap...
# Number of photons on captor elements: 5633
# Done!
# Number of photons received in total is 5633
# ---------------------------------
# ---------------------------------
# Test Tmin = 100.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 28
# building captor photonmap...
# Number of photons on captor elements: 5782
# Done!
# Number of photons received in total is 5782
# ---------------------------------
# ---------------------------------
# Test Tmin = 1000.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 12
# building captor photonmap...
# Number of photons on captor elements: 2008
# Done!
# Number of photons received in total is 2008
# ---------------------------------
# ---------------------------------
# Test Tmin = 10000.0
# Maximum number of threads is 8
# nb photons per lights: 125000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 0
# Number of photons received in total is 0
# ---------------------------------

# %% [markdown]
# Test Tmin in scene with only lamps and captors

# %%
simulator.test_t_min(int(1e7), 1e-6, 11, True)
# Out:
# Transparent material: Makrolon
# Backface Culling ON
# ---------------------------------
# Test Tmin = 1e-06
# Number of photons received in total is 486
# ---------------------------------
# ---------------------------------
# Test Tmin = 1e-05
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 4
# building captor photonmap...
# Number of photons on captor elements: 486
# Done!
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 4
# building captor photonmap...
# Number of photons on captor elements: 486
# Done!
# Number of photons received in total is 486
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.0001
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 4
# building captor photonmap...
# Number of photons on captor elements: 487
# Done!
# Number of photons received in total is 487
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.001
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 4
# building captor photonmap...
# Number of photons on captor elements: 487
# Done!
# Number of photons received in total is 487
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.01
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 4
# building captor photonmap...
# Number of photons on captor elements: 487
# Done!
# Number of photons received in total is 487
# ---------------------------------
# ---------------------------------
# Test Tmin = 0.1
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 4
# building captor photonmap...
# Number of photons on captor elements: 485
# Done!
# Number of photons received in total is 485
# ---------------------------------
# ---------------------------------
# Test Tmin = 1.0
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 4
# building captor photonmap...
# Number of photons on captor elements: 487
# Done!
# Number of photons received in total is 487
# ---------------------------------
# ---------------------------------
# Test Tmin = 10.0
# Maximum number of threads is Number of photons received in total is8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 3
# building captor photonmap...
# Number of photons on captor elements: 496
# Done!
#  496
# ---------------------------------
# ---------------------------------
# Test Tmin = 100.0
# Maximum number of threads is Number of photons received in total is 492
# ---------------------------------
# ---------------------------------
# Test Tmin = 1000.0
# 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 2
# building captor photonmap...
# Number of photons on captor elements: 492
# Done!
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 1
# building captor photonmap...
# Number of photonsNumber of photons received in total is 489
# ---------------------------------
# ---------------------------------
# Test Tmin = 10000.0
#  on captor elements: 489
# Done!
# Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
# Tracing photons from light n° 2/8...
# Tracing photons from light n° 3/8...
# Tracing photons from light n° 4/8...
# Tracing photons from light n° 5/8...
# Tracing photons from light n° 6/8...
# Tracing photons from light n° 7/8...
# Tracing photons from light n° 8/8...
# Max depth possible: 0
# Number of photons received in total is 0
# ---------------------------------
