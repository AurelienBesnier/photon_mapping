# %% [raw]
# Import the modules necessary for simulation

# %%
from modules.Simulator import *

# %% [raw]
# Run the simulation

# %%
simulator = Simulator()
simulator.readConfiguration("simulation.ini")
simulator.setupRoom("./assets/testChamber.rad", "./PO")
simulator.setupCaptor("./captors/captors_expe1.csv")
#simulator.setupPlant("./assets/rose-simple4.lpy")
simulator.run()
# Out:
# Write .obj
# Write .obj.mtl
# Transparent material: Makrolon
# Backface Culling ON
# Build photonMap...
# Done!Maximum number of threads is 8
# nb photons per lights: 1250000
#
# Tracing photons from light n° 1/8...
#
# Tracing photons from light n° 2/8...
#
# Tracing photons from light n° 3/8...
#
# Tracing photons from light n° 4/8...
#
# Tracing photons from light n° 5/8...
#
# Tracing photons from light n° 6/8...
#
# Tracing photons from light n° 7/8...
#
# Tracing photons from light n° 8/8...
# Max depth possible: 30
# building captor photonmap...
# Number of photons on captor elements: 47861
# Done!
#
# 47861
# writing captor energy...
# captor n°0 has 141 photons on it
# captor n°1 has 149 photons on it
# captor n°2 has 156 photons on it
# captor n°3 has 188 photons on it
# captor n°4 has 179 photons on it
# captor n°5 has 166 photons on it
# captor n°6 has 209 photons on it
# captor n°7 has 194 photons on it
# captor n°8 has 168 photons on it
# captor n°9 has 180 photons on it
# captor n°10 has 225 photons on it
# captor n°11 has 189 photons on it
# captor n°12 has 132 photons on it
# captor n°13 has 148 photons on it
# captor n°14 has 152 photons on it
# captor n°15 has 175 photons on it
# captor n°16 has 201 photons on it
# captor n°17 has 213 photons on it
# captor n°18 has 195 photons on it
# captor n°19 has 221 photons on it
# captor n°20 has 198 photons on it
# captor n°21 has 226 photons on it
# captor n°22 has 172 photons on it
# captor n°23 has 221 photons on it
# captor n°24 has 155 photons on it
# captor n°25 has 142 photons on it
# captor n°26 has 160 photons on it
# captor n°27 has 161 photons on it
# captor n°28 has 186 photons on it
# captor n°29 has 213 photons on it
# captor n°30 has 172 photons on it
# captor n°31 has 187 photons on it
# captor n°32 has 210 photons on it
# captor n°33 has 205 photons on it
# captor n°34 has 188 photons on it
# captor n°35 has 214 photons on it
# captor n°36 has 137 photons on it
# captor n°37 has 148 photons on it
# captor n°38 has 170 photons on it
# captor n°39 has 191 photons on it
# captor n°40 has 199 photons on it
# captor n°41 has 171 photons on it
# captor n°42 has 196 photons on it
# captor n°43 has 190 photons on it
# captor n°44 has 201 photons on it
# captor n°45 has 203 photons on it
# captor n°46 has 193 photons on it
# captor n°47 has 208 photons on it
# captor n°48 has 144 photons on it
# captor n°49 has 145 photons on it
# captor n°50 has 173 photons on it
# captor n°51 has 162 photons on it
# captor n°52 has 160 photons on it
# captor n°53 has 178 photons on it
# captor n°54 has 185 photons on it
# captor n°55 has 224 photons on it
# captor n°56 has 186 photons on it
# captor n°57 has 183 photons on it
# captor n°58 has 197 photons on it
# captor n°59 has 205 photons on it
# captor n°60 has 121 photons on it
# captor n°61 has 162 photons on it
# captor n°62 has 150 photons on it
# captor n°63 has 159 photons on it
# captor n°64 has 179 photons on it
# captor n°65 has 211 photons on it
# captor n°66 has 178 photons on it
# captor n°67 has 174 photons on it
# captor n°68 has 190 photons on it
# captor n°69 has 217 photons on it
# captor n°70 has 202 photons on it
# captor n°71 has 215 photons on it
# captor n°72 has 137 photons on it
# captor n°73 has 132 photons on it
# captor n°74 has 152 photons on it
# captor n°75 has 178 photons on it
# captor n°76 has 204 photons on it
# captor n°77 has 210 photons on it
# captor n°78 has 167 photons on it
# captor n°79 has 225 photons on it
# captor n°80 has 212 photons on it
# captor n°81 has 241 photons on it
# captor n°82 has 217 photons on it
# captor n°83 has 164 photons on it
# captor n°84 has 134 photons on it
# captor n°85 has 123 photons on it
# captor n°86 has 153 photons on it
# captor n°87 has 179 photons on it
# captor n°88 has 175 photons on it
# captor n°89 has 183 photons on it
# captor n°90 has 193 photons on it
# captor n°91 has 187 photons on it
# captor n°92 has 195 photons on it
# captor n°93 has 205 photons on it
# captor n°94 has 201 photons on it
# captor n°95 has 215 photons on it
# captor n°96 has 140 photons on it
# captor n°97 has 132 photons on it
# captor n°98 has 153 photons on it
# captor n°99 has 138 photons on it
# captor n°100 has 163 photons on it
# captor n°101 has 174 photons on it
# captor n°102 has 195 photons on it
# captor n°103 has 189 photons on it
# captor n°104 has 178 photons on it
# captor n°105 has 207 photons on it
# captor n°106 has 175 photons on it
# captor n°107 has 172 photons on it
# captor n°108 has 118 photons on it
# captor n°109 has 121 photons on it
# captor n°110 has 136 photons on it
# captor n°111 has 159 photons on it
# captor n°112 has 155 photons on it
# captor n°113 has 146 photons on it
# captor n°114 has 176 photons on it
# captor n°115 has 185 photons on it
# captor n°116 has 177 photons on it
# captor n°117 has 159 photons on it
# captor n°118 has 195 photons on it
# captor n°119 has 164 photons on it
# captor n°120 has 138 photons on it
# captor n°121 has 132 photons on it
# captor n°122 has 152 photons on it
# captor n°123 has 186 photons on it
# captor n°124 has 174 photons on it
# captor n°125 has 188 photons on it
# captor n°126 has 210 photons on it
# captor n°127 has 214 photons on it
# captor n°128 has 206 photons on it
# captor n°129 has 217 photons on it
# captor n°130 has 191 photons on it
# captor n°131 has 210 photons on it
# captor n°132 has 129 photons on it
# captor n°133 has 135 photons on it
# captor n°134 has 160 photons on it
# captor n°135 has 177 photons on it
# captor n°136 has 188 photons on it
# captor n°137 has 189 photons on it
# captor n°138 has 202 photons on it
# captor n°139 has 225 photons on it
# captor n°140 has 207 photons on it
# captor n°141 has 220 photons on it
# captor n°142 has 255 photons on it
# captor n°143 has 213 photons on it
# captor n°144 has 145 photons on it
# captor n°145 has 151 photons on it
# captor n°146 has 147 photons on it
# captor n°147 has 180 photons on it
# captor n°148 has 179 photons on it
# captor n°149 has 226 photons on it
# captor n°150 has 213 photons on it
# captor n°151 has 213 photons on it
# captor n°152 has 247 photons on it
# captor n°153 has 214 photons on it
# captor n°154 has 242 photons on it
# captor n°155 has 244 photons on it
# captor n°156 has 139 photons on it
# captor n°157 has 140 photons on it
# captor n°158 has 168 photons on it
# captor n°159 has 196 photons on it
# captor n°160 has 189 photons on it
# captor n°161 has 252 photons on it
# captor n°162 has 230 photons on it
# captor n°163 has 247 photons on it
# captor n°164 has 236 photons on it
# captor n°165 has 258 photons on it
# captor n°166 has 231 photons on it
# captor n°167 has 235 photons on it
# captor n°168 has 156 photons on it
# captor n°169 has 155 photons on it
# captor n°170 has 175 photons on it
# captor n°171 has 206 photons on it
# captor n°172 has 209 photons on it
# captor n°173 has 245 photons on it
# captor n°174 has 272 photons on it
# captor n°175 has 256 photons on it
# captor n°176 has 249 photons on it
# captor n°177 has 278 photons on it
# captor n°178 has 256 photons on it
# captor n°179 has 242 photons on it
# captor n°180 has 184 photons on it
# captor n°181 has 172 photons on it
# captor n°182 has 172 photons on it
# captor n°183 has 219 photons on it
# captor n°184 has 215 photons on it
# captor n°185 has 284 photons on it
# captor n°186 has 277 photons on it
# captor n°187 has 280 photons on it
# captor n°188 has 297 photons on it
# captor n°189 has 273 photons on it
# captor n°190 has 270 photons on it
# captor n°191 has 259 photons on it
# captor n°192 has 139 photons on it
# captor n°193 has 138 photons on it
# captor n°194 has 182 photons on it
# captor n°195 has 189 photons on it
# captor n°196 has 263 photons on it
# captor n°197 has 302 photons on it
# captor n°198 has 303 photons on it
# captor n°199 has 299 photons on it
# captor n°200 has 300 photons on it
# captor n°201 has 287 photons on it
# captor n°202 has 299 photons on it
# captor n°203 has 313 photons on it
# captor n°204 has 130 photons on it
# captor n°205 has 139 photons on it
# captor n°206 has 168 photons on it
# captor n°207 has 227 photons on it
# captor n°208 has 259 photons on it
# captor n°209 has 314 photons on it
# captor n°210 has 291 photons on it
# captor n°211 has 343 photons on it
# captor n°212 has 303 photons on it
# captor n°213 has 268 photons on it
# captor n°214 has 242 photons on it
# captor n°215 has 262 photons on it
# captor n°216 has 135 photons on it
# captor n°217 has 150 photons on it
# captor n°218 has 182 photons on it
# captor n°219 has 206 photons on it
# captor n°220 has 216 photons on it
# captor n°221 has 283 photons on it
# captor n°222 has 299 photons on it
# captor n°223 has 303 photons on it
# captor n°224 has 277 photons on it
# captor n°225 has 286 photons on it
# captor n°226 has 280 photons on it
# captor n°227 has 242 photons on it
# captor n°228 has 130 photons on it
# captor n°229 has 134 photons on it
# captor n°230 has 180 photons on it
# captor n°231 has 196 photons on it
# captor n°232 has 234 photons on it
# captor n°233 has 261 photons on it
# captor n°234 has 255 photons on it
# captor n°235 has 263 photons on it
# captor n°236 has 248 photons on it
# captor n°237 has 250 photons on it
# captor n°238 has 238 photons on it
# captor n°239 has 225 photons on it
# Done!
# Time taken: 3.817366600036621
